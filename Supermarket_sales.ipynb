# %% [markdown]
# # 🛒 Supermarket Sales Analysis
#
# ## 🎯 Objective
# To analyze supermarket sales data using statistical and visual methods and extract key business insights.
#
# **Tools Used**: Python, Pandas, Seaborn, Matplotlib

# %%
pip install matplotlib seaborn pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set visualization styles
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %% [markdown]
# ## 📂 2. Load Dataset
#
# Load the CSV into a DataFrame and take a peek at the first few rows.

# %%
# Load the dataset
df = pd.read_csv("C:/Users/anjul/Downloads/SuperMarket_Analysis.csv")

# %% [markdown]
# ## 📄 3. Basic Exploration
#
# - Check dataset info, descriptive statistics
# - See distribution of key categorical variables

# %%
# Basic exploration
print("Dataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Sales                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
print("\nDescriptive Statistics:")
print(df.describe())
# Out:
# Descriptive Statistics:
#         Unit price     Quantity       Tax 5%        Sales        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
print("\nValue Counts:")
print(df['Gender'].value_counts())
print(df['Payment'].value_counts())
# Out:
# Value Counts:
# Gender
# Female    571
# Male      429
# Name: count, dtype: int64
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %% [markdown]
# ## ❓ 4. Missing Values
#
# Verify that there are no nulls in the dataset.

# %%
# Check for Missing Values
print (df.isnull().sum())
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Sales                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# ## 📊 5. Univariate Analysis
#
# ### 5.1 Distribution of Sales
# Use a histogram to understand the spread of the `Sales` column.

# %%
# Histogram of Sales
sns.histplot(df['Sales'], bins=20, kde=True)
plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### 5.2 Sales by Gender
# Use a boxplot to compare sales distributions between genders.

# %%
# Boxplot: Sales by Gender
sns.boxplot(data=df, x ='Gender', y = 'Sales')
plt.title("Sales by Gender")
plt.show()

# %% [markdown]
# ### 5.3 Product Line Frequency
# Count how many transactions occurred in each product line.

# %%
# Countplot: Product Lines
sns.countplot(data=df, y='Product line', order=df['Product line'].value_counts().index)
plt.title("Product Line Frequency")
plt.show()

# %% [markdown]
# ## 🔗 6. Bivariate Analysis
#
# ### 6.1 Quantity vs Sales
# Scatterplot to see how quantity sold relates to total sales.

# %%
# Scatterplot: Quantity vs Sales
sns.scatterplot(data=df, x='Quantity', y='Sales')
plt.title("Quantity vs Sales")
plt.show()

# %% [markdown]
# ### 6.2 Sales by City
# Boxplot to compare sales distributions across cities.

# %%
# boxplot: City vs Sales
sns.boxplot(data=df, x='City', y='Sales')
plt.title("Sales Distribution by City")
plt.show()

# %% [markdown]
# ### 6.3 Payment Method Distribution
# Countplot for payment types.

# %%
# Countplot: Payment Method
sns.countplot(data=df, x='Payment')
plt.title("Payment Method Distribution")
plt.show()

# %% [markdown]
# ## 🔍 7. Correlation Analysis
#
# Use a heatmap to uncover relationships among numeric features.

# %%
# Correlation Heatmap
plt.figure(figsize=(8,4))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## 📈 9. Pairwise Relationships
#
# Use pairplot to visualize pairwise scatterplots and distributions.

# %%
# pairplot 
sns.pairplot(df[['Sales', 'Quantity', 'Tax 5%', 'Unit price','cogs']])
plt.show()

# %% [markdown]
# ## ✅ 10. Summary of Findings

# %%
# Summary of Findings 
summary = """
Summary of Insights:
- 'Food and beverages' and 'Health and beauty' are the most popular product lines.
- Ewallet is the most preferred payment method.
- Male and Female customers spend similarly.
- Cities show variation in average sales, indicating different consumer behavior.
- Strong correlation between 'Sales', 'Tax', and 'COGS'.
"""
print(summary)
# Out:
# Summary of Insights:
# - 'Food and beverages' and 'Health and beauty' are the most popular product lines.
# - Ewallet is the most preferred payment method.
# - Male and Female customers spend similarly.
# - Cities show variation in average sales, indicating different consumer behavior.
# - Strong correlation between 'Sales', 'Tax', and 'COGS'.
